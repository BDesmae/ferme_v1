# %%
import pandas as pd

# %%
temperature = pd.read_table("C:/Users/Dell/Desktop/ferme_eval/temperature.csv", names=['date','mini','terrain','maxi','moyenne'], skiprows = [0], engine='python', sep='\;|,')

# %%
temperature
# Out:
#       date  mini  terrain  maxi  moyenne
# 0    01/14    -4       13    40       29
# 1    01/15   -11       11    33       15
# 2    01/15    -7       28    40       20
# 3    01/15    -1       33    18       18
# 4    01/17   -11       38    29       28
# 5    01/15    -9       38    36       29
# 6    01/15   -11       56    38       13
# 7    01/15    -7       58    41       24
# 8    01/15    -2       99    31       14
# 9    01/16   -12        6    26       21
# 10   01/16   -14       30    38       20
# 11   01/16   -13       44    28       18
# 12   01/16   -14       75    45       13
# 13   01/16     1       98    25       24
# 14   01/17    -2       28    25       24
# 15   01/17    -2       65    42       17
# 16   01/17     0       65    29       23
# 17   01/17    -1       79    26       29
# 18   01/18   -12       20    32       16
# 19   01/19   -13       19    44       17
# 20   01/19     0       20    33       23
# 21   01/19   -12       28    35       22
# ...

# %%
temperature.describe()
# Out:
#              mini     terrain        maxi     moyenne
# count  900.000000  900.000000  900.000000  900.000000
# mean    -6.671111   50.947778   29.056667   19.241111
# std      5.203816   28.386937   11.150308    5.728049
# min    -15.000000    1.000000   10.000000   10.000000
# 25%    -11.000000   26.000000   20.000000   14.000000
# 50%     -7.000000   52.000000   29.000000   19.000000
# 75%     -2.000000   74.000000   39.000000   24.000000
# max      2.000000  100.000000   48.000000   29.000000

# %%
for i in range(len(temperature)):
    if temperature.moyenne[i] > temperature.maxi[i]:
        temp = temperature.moyenne[i]
        temperature.moyenne[i] = temperature.maxi[i]
        temperature.maxi[i] = temp
# Out:
# Empty DataFrame
# Columns: [date, mini, terrain, maxi, moyenne]
# Index: []

# %%
for i in range(len(temperature)):
    moy = (temperature.mini[i] + temperature.maxi[i])/2
    if temperature.moyenne[i] == temperature.maxi[i]:
        temperature.moyenne[i] = moy
# Out:
# C:\Users\Dell\Miniconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
temperature[temperature['moyenne'] == temperature['maxi']]
# Out:
# Empty DataFrame
# Columns: [date, mini, terrain, maxi, moyenne]
# Index: []
